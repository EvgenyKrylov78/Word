# %% [markdown]
# <a href="https://colab.research.google.com/github/EvgenyKrylov78/Word/blob/main/Copy_of_Word22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open('/content/auto_.txt', "r", encoding="utf-8")
text = f.read()

# %%
type(text)
# Out:
# str

# %%
len(text)
# Out:
# 1570

# %%
text[:800]
# Out:
# '\ufeffToyota Cresta - 1995 - «Старая toyota или новая Lada?»  \n5\nХочу поделиться эмоциями, которые я испытал владея автомобилем Toyota cresta jzx90 tourer S уже более года.И так, cresta jzx90: объем двигателя 2.5 - 180 л.с. это достаточно большой и комфортный корабль. Несмотря на габариты автомобиля (4750*1750*1390) им легко и комфортно управлять как в городе, так и на трассе. В салоне данного автомобиля чувствуется высокий представительский класс. Это можно заметитьтишиной в салоне, мягкими и просторными сиденьями, удобным расположение консоли управления и многим многим другим.Надежность двигателя 1JZ-GE известно по всему миру. Моя машина с 1995 г.в. и пробег 320тыс. (я думаю где-то еще сотни 2 скрутили умельцы..) и спустя 23 года этот двигатель чувствует себя прекрасно и едет на все свои 180 '

# %%
# перевод в единый регистр (например, нижний)
text = text.lower()

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
type(string.punctuation)
# Out:
# str

# %%
spec_chars = string.punctuation + '\n\xa0«»\t—…'

# %%
# %%time
text = "".join([ch for ch in text if ch not in spec_chars])
# Out:
# CPU times: user 600 µs, sys: 0 ns, total: 600 µs
# Wall time: 625 µs

# %%
import re
text = re.sub('\n', '', text)

# %%
def remove_chars_from_text(text, chars):
    return "".join([ch for ch in text if ch not in chars])

# %%
# %%time
text = remove_chars_from_text(text, spec_chars)
# Out:
# CPU times: user 516 µs, sys: 0 ns, total: 516 µs
# Wall time: 535 µs

# %%
# %%time
text = remove_chars_from_text(text, string.digits)
# Out:
# CPU times: user 424 µs, sys: 0 ns, total: 424 µs
# Wall time: 435 µs

# %%
pip install nltk

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import word_tokenize
text_tokens = word_tokenize(text)

# %%
print(type(text_tokens), len(text_tokens))
text_tokens[:10]
# Out:
# <class 'list'> 228
# ['\ufefftoyota',
#  'cresta',
#  'старая',
#  'toyota',
#  'или',
#  'новая',
#  'lada',
#  'хочу',
#  'поделиться',
#  'эмоциями']

# %%
text = nltk.Text(text_tokens)
print(type(text))
text[:10]
# Out:
# <class 'nltk.text.Text'>
# ['\ufefftoyota',
#  'cresta',
#  'старая',
#  'toyota',
#  'или',
#  'новая',
#  'lada',
#  'хочу',
#  'поделиться',
#  'эмоциями']

# %%
# %%time
from nltk.probability import FreqDist
fdist = FreqDist(text)
fdist
# Out:
# CPU times: user 309 µs, sys: 58 µs, total: 367 µs
# Wall time: 370 µs

# %%
fdist.most_common(5)
# Out:
# [('и', 11), ('на', 6), ('в', 6), ('я', 5), ('cresta', 3)]

# %%
fdist.plot(30,cumulative=False)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
russian_stopwords = stopwords.words("russian")
russian_stopwords.extend(['это', 'нею'])

# %%
print(stopwords.words('russian'))
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
print(len(russian_stopwords))
# russian_stopwords
# Out:
# 153

# %%
# %%time
text_tokens = [token.strip() for token in text_tokens if token not in russian_stopwords]
# Out:
# CPU times: user 481 µs, sys: 0 ns, total: 481 µs
# Wall time: 485 µs

# %%
print(len(text_tokens))
# Out:
# 151

# %%
text = nltk.Text(text_tokens)

# %%
fdist_sw = FreqDist(text)
fdist_sw.most_common(10)
# Out:
# [('cresta', 3),
#  ('toyota', 3),
#  ('lada', 3),
#  ('автомобиля', 3),
#  ('старая', 2),
#  ('новая', 2),
#  ('хочу', 2),
#  ('которые', 2),
#  ('jzx', 2),
#  ('двигателя', 2)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text_raw = " ".join(text)

# %%
wordcloud = WordCloud(
                    width = 2000, 
                      height = 1500, 
                      random_state=1, 
                      background_color='black', 
                      margin=20, 
                      colormap='Pastel1', 
                      collocations=False).generate(text_raw)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
